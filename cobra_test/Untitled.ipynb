# %%
import cobra
import cobra.test
from os.path import join

from os import listdir
from os.path import isfile, join

data_dir = "/git_projects/misc_scripts/cobra_test/"

listdir()

# Load in data from Simon 2014 paper
# cobra.io.read_sbml_model("TS4_Model.xml")

cobra.io.sbml.validate_sbml_model("13563491390073.sbml")
# Out:
# (<Model model_13563491390073 at 0x7fd98bca1400>,
#  {'SBML_FATAL': [],
#   'SBML_ERROR': [],
#   'SBML_SCHEMA_ERROR': [],
#   'SBML_WARNING': [],
#   'COBRA_FATAL': [],
#   'COBRA_ERROR': ['No objective coefficients in model. Unclear what should be optimized'],
#   'COBRA_WARNING': ['Model does not contain SBML fbc package information.',
#    "SBML package 'layout' not supported by cobrapy, information is not parsed",
#    "SBML package 'render' not supported by cobrapy, information is not parsed",
#    'Missing lower flux bound set to \'-1000.0\' for  reaction: \'<Reaction reaction_627_8_8 "alanine aminotransferase">\'',
#    'Missing upper flux bound set to \'1000.0\' for  reaction: \'<Reaction reaction_627_8_8 "alanine aminotransferase">\'',
#    'Missing lower flux bound set to \'-1000.0\' for  reaction: \'<Reaction reaction_575_70_30 "carbonate dehydratase">\'',
# ...
